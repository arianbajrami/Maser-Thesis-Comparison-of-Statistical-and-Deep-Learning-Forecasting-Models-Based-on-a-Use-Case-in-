# %%
colours = {'black': [0,0,0],
             'darkblue': '#1F4E79', 
             'middle_blue': '#3795D5',
             'light_blue' : '#D7E6F5',
             '1B' : '#356CA5',
             '1D' : '#8AB5E1',
             'dark_red': '#AB2626',
             'dark_orange':'#B77201',
             'gold':'#F7D507',
             'middle_orange' : '#EC9302',
             'dark_green' : '#41641A',
             'middle_green' : '#92D050',
             'dark_gray' : '#515151'
             }

# %%
R2 = {
    'Average' : -6.89,
    'Simple Moving Average' : 24.48, 
    'Naive' : 9.04,
    'Linear Regression' : 87.33,
    'DES' : 55.78,
    'SARMA' : 64.5,
    'SARMAX' : 88.87,
    'Bagging Ensemble' :92.07,
    'Random Forest' : 92.15,
    'Gradient Boosting' : 94.92,
    'MLP' : 92.50,
    'CNN' : 93.44,
    'LSTM' : 93.95,
    'Hetorogenous Ensemble': 92.71,
}

# %%
R2_adj = {
    'Average' : -6.89,
    'Simple Moving Average' : 24.48, 
    'Naive' : 9.04,
    'Linear Regression' : 87.33,
    'DES' : 55.78,
    'SARMA' : 64.5,
    'SARMAX' : 88.75,
    'Bagging Ensemble' : 91.99,
    'Random Forest' :   92.07,
    'Gradient Boosting' : 94.86,
    'MLP' : 92.42,
    'CNN' : 93.37,
    'LSTM' : 93.88,
    'Hetorogenous Ensemble': 92.63,
}

# %%
mae = {
    'Average' : 129.19,
    'Simple Moving Average' : 99.64, 
    'Naive' : 108.19,
    'Linear Regression' : 42.37,
    'DES' : 72.92,
    'SARMA' : 62.67,
    'SARMAX' : 39.76,
    'Bagging Ensemble' : 
    'Random Forest' :  
    'Gradient Boosting' : 
    'MLP' : 
    'CNN' : 
    'LSTM' : 29.53
    'Hetorogenous Ensemble': 32.36
}

# %%
mape = {
    'Average' : 28.71,
    'Moving Average' : 24.11, 
    'Naive' : 24.78,
    'Linear Regression' : 9.87,
    'Exponential Smoothing' : 16.36,
    'SARMA' : 14.09,
    'SARMAX' : 8.29,
    'Bagging Ensemble' :
    'Random Forest' :
    'Gradient Boosting' : 
    'MLP' : 
    'CNN' : 
    'LSTM' : 6.34
    'Hetorogenous Ensemble': 6.76
}

# %%
rmse = {
    'Average' : 153.92,
    'Simple Moving Average' : 131.92, 
    'Naive' : 141.99,
    'Linear Regression' : 52.99,
    'Exponential Smoothing' : 99.0,
    'SARMA' : 88.7,
    'SARMAX' : 49.68,
    'Bagging Ensemble' : 42.22,
    'Random Forest' : 41.71,  
    'Gradient Boosting' : 33.56,
    'MLP' : 41.58,
    'CNN' : 38.14,
    'LSTM' : 36.68,
    'Hetorogenous Ensemble': 40.24
}

# %%
rmse = {k: v for k, v in sorted(rmse.items(), key=lambda item: item[1])}

# %%
models = list(rmse.keys())
models
# Out:
# ['Gradient Boosting',
#  'LSTM',
#  'CNN',
#  'Hetorogenous Ensemble',
#  'MLP',
#  'Random Forest',
#  'Bagging Ensemble',
#  'SARMAX',
#  'Linear Regression',
#  'SARMA',
#  'Moving Average',
#  'Exponential Smoothing',
#  'Simple Average',
#  'Naive']

# %%
rmse_values = list(rmse.values())
rmse_values
# Out:
# [33.56,
#  36.68,
#  38.14,
#  40.24,
#  41.58,
#  41.71,
#  42.22,
#  49.68,
#  52.99,
#  74.3,
#  97.31,
#  106.71,
#  154.43,
#  185.67]

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.figure(figsize = (24,8))
plt.barh(models, rmse_values,  color = colours.get('1B'))
plt.grid()
plt.title('Comparison of the RMSE of the created models')
plt.gca().invert_yaxis()
plt.rcParams.update({'font.size': 14})
plt.xlabel('RMSE in $g_{CO2}/kWh$')
plt.show()

# %%
IS = {
    'Exponential Smoothing' : 277.03,
    'SARMA' : 355.54,
    'SARMAX' : 153.78,
    'Bagging Ensemble' : 178.23,
    'Random Forest' : 261.63,  
    'Gradient Boosting' : 132.92,
    'MLP' : 90.16,
    'CNN' : 98.6,
    'LSTM' : 165.18,
    'Hetorogenous Ensemble': 107.75
}

# %%
IS = {k: v for k, v in sorted(IS.items(), key=lambda item: item[1])}

# %%
models_IS = list(IS.keys())
models_IS
# Out:
# ['MLP',
#  'CNN',
#  'Hetorogenous Ensemble',
#  'Gradient Boosting',
#  'SARMAX',
#  'LSTM',
#  'Bagging Ensemble',
#  'Random Forest',
#  'SARMA',
#  'Exponential Smoothing']

# %%
IS_values = list(IS.values())
IS_values
# Out:
# [90.16, 98.6, 107.75, 132.92, 153.78, 165.18, 178.23, 261.63, 299.38, 301.63]

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.figure(figsize = (24,8))
plt.barh(models_IS, IS_values,  color = colours.get('1B'))
plt.grid()
plt.title('Comparison of the interval score of the created models')
plt.gca().invert_yaxis()
plt.rcParams.update({'font.size': 12})
plt.xlabel('IS in $g_{CO2}/kWh$')
plt.show()

# %%
QS_low = {
    'Gradient Boosting' : 2.21,
    'Bagging Ensemble' : 2.88,
    'SARMAX' : 2.74,
    'LSTM' : 3.39,
    'Random Forest' : 3.78,
    'CNN' : 3.4,
    'SARMA' : 5.0,
    'Hetorogenous Ensemble': 2.18,
    'MLP' : 2.6,
    'Exponential Smoothing' : 5.41,
}

# %%
QS_high = {
    'Gradient Boosting' : 2.78,
    'Bagging Ensemble' : 2.27,
    'SARMAX' : 3.16,
    'LSTM' : 3.75,
    'Random Forest' : 2.84,  
    'CNN' : 4.94,
    'SARMA' : 5.39,
    'Hetorogenous Ensemble': 6.21,
    'MLP' : 8.96,
    'Exponential Smoothing' : 17.02,
}

# %%
models_QS = list(QS_high.keys())

# %%
QS_low_values = list(QS_low.values())
QS_high_values = list(QS_high.values())

QS_low_values, QS_high_values
# Out:
# ([2.21, 2.88, 2.74, 3.39, 3.78, 3.4, 4.15, 2.18, 2.6, 6.1],
#  [2.78, 2.27, 3.16, 3.75, 2.84, 4.94, 4.45, 6.21, 8.96, 16.92])

# %%
from cProfile import label


plt.figure(figsize = (24,8))
yaxis = np.arange(len(QS_low))
plt.barh(yaxis -0.2, QS_low_values, 0.4, color = colours.get('1B'), label = 'Lower Quantile Score')
plt.barh(yaxis +0.2, QS_high_values, 0.4,  color = colours.get('1D'), label = 'Higher Quantile Score')
plt.yticks(yaxis, models_QS)
plt.grid()
plt.title('Comparison of the quantile score of the created models')
plt.gca().invert_yaxis()
plt.rcParams.update({'font.size': 12})
plt.xlabel('QS in $g_{CO2}/kWh$')
plt.legend(loc = 'best')
plt.show()
